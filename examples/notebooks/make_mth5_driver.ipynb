# %%
# Make MTH5 drive. 
import pandas as pd
import sys
from mth5.clients.make_mth5 import MakeMTH5
from mth5 import mth5, timeseries

# %%
# Print poath at current directory. 
import os
os.getcwd()
# Out:
# '/Users/tronan/Desktop/mth5/examples/notebooks'

# %%
# Uncomment to test multi network MTH5s

# EMCAY10LFE = ['EM', 'CAY10', '', 'LFE', '2019-10-07T00:00:00', '2019-10-30T00:00:00'] 
# EMCAY10LFN = ['EM', 'CAY10', '', 'LFN', '2019-10-07T00:00:00', '2019-10-30T00:00:00'] 
# EMCAY10LFZ = ['EM', 'CAY10', '', 'LFZ', '2019-10-07T00:00:00', '2019-10-30T00:00:00'] 
# EMCAY10LQE = ['EM', 'CAY10', '', 'LQE', '2019-10-07T00:00:00', '2019-10-30T00:00:00'] 
# EMCAY10LQN = ['EM', 'CAY10', '', 'LQN', '2019-10-07T00:00:00', '2019-10-30T00:00:00'] 
ZUCAS04LQ1 = ['ZU', 'CAS04', '', 'LQE', '2020-06-02T19:00:00', '2020-07-13T19:00:00']
ZUCAS04LQ2 = ['ZU', 'CAS04', '', 'LQN', '2020-06-02T19:00:00', '2020-07-13T19:00:00']
ZUCAS04BF1 = ['ZU', 'CAS04', '', 'LFE', '2020-06-02T19:00:00', '2020-07-13T19:00:00']
ZUCAS04BF2 = ['ZU', 'CAS04', '', 'LFN', '2020-06-02T19:00:00', '2020-07-13T19:00:00']
ZUCAS04BF3 = ['ZU', 'CAS04', '', 'LFZ', '2020-06-02T19:00:00', '2020-07-13T19:00:00']
ZUNRV08LQ1 = ['ZU', 'NVR08', '', 'LQE', '2020-06-02T19:00:00', '2020-07-13T19:00:00']
ZUNRV08LQ2 = ['ZU', 'NVR08', '', 'LQN', '2020-06-02T19:00:00', '2020-07-13T19:00:00']
ZUNRV08BF1 = ['ZU', 'NVR08', '', 'LFE', '2020-06-02T19:00:00', '2020-07-13T19:00:00']
ZUNRV08BF2 = ['ZU', 'NVR08', '', 'LFN', '2020-06-02T19:00:00', '2020-07-13T19:00:00']
ZUNRV08BF3 = ['ZU', 'NVR08', '', 'LFZ', '2020-06-02T19:00:00', '2020-07-13T19:00:00']
metadata_list = [ZUCAS04LQ1, ZUCAS04LQ2, ZUCAS04BF1, ZUCAS04BF2, ZUCAS04BF3, ZUNRV08LQ1, 
                 ZUNRV08LQ2, ZUNRV08BF1, ZUNRV08BF2, ZUNRV08BF3
                 # , EMCAY10LFE, EMCAY10LFN, 
                 # EMCAY10LFZ, EMCAY10LQE, EMCAY10LQN]

# Turn list into dataframe
metadata_df =  pd.DataFrame(metadata_list, columns=['net', 'sta', 'loc', 'chan', 'startdate', 'enddate'])

# %%
metadata_df
# Out:
#    net    sta loc chan            startdate              enddate
# 0   ZU  CAS04      LQE  2020-06-02T19:00:00  2020-07-13T19:00:00
# 1   ZU  CAS04      LQN  2020-06-02T19:00:00  2020-07-13T19:00:00
# 2   ZU  CAS04      LFE  2020-06-02T19:00:00  2020-07-13T19:00:00
# 3   ZU  CAS04      LFN  2020-06-02T19:00:00  2020-07-13T19:00:00
# 4   ZU  CAS04      LFZ  2020-06-02T19:00:00  2020-07-13T19:00:00
# 5   ZU  NVR08      LQE  2020-06-02T19:00:00  2020-07-13T19:00:00
# 6   ZU  NVR08      LQN  2020-06-02T19:00:00  2020-07-13T19:00:00
# 7   ZU  NVR08      LFE  2020-06-02T19:00:00  2020-07-13T19:00:00
# 8   ZU  NVR08      LFN  2020-06-02T19:00:00  2020-07-13T19:00:00
# 9   ZU  NVR08      LFZ  2020-06-02T19:00:00  2020-07-13T19:00:00
# 10  EM  CAY10      LFE  2019-10-07T00:00:00  2019-10-30T00:00:00
# 11  EM  CAY10      LFN  2019-10-07T00:00:00  2019-10-30T00:00:00
# 12  EM  CAY10      LFZ  2019-10-07T00:00:00  2019-10-30T00:00:00
# 13  EM  CAY10      LQE  2019-10-07T00:00:00  2019-10-30T00:00:00
# 14  EM  CAY10      LQN  2019-10-07T00:00:00  2019-10-30T00:00:00

# %%
mth5_file = MakeMTH5.make_mth5_from_fdsnclient(MakeMTH5(), metadata_df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-431194580c76> in <module>
# ----> 1 mth5_file = MakeMTH5.make_mth5_from_fdsnclient(MakeMTH5(), metadata_df)
#
# ~/Desktop/Projects/mth5/mth5/clients/make_mth5.py in make_mth5_from_fdsnclient(self, df, path, client)
#      46         # initiate MTH5 file
#      47         if len(net_list) != 1:
# ---> 48             raise AttributeError('MTH5 supports one survey/network per container.')
#      49         m = MTH5()
#      50         streams = obsread()
#
# AttributeError: MTH5 supports one survey/network per container.

# %%
# Check the MTH5
mth5_obj = mth5.MTH5()
mth5_obj.open_mth5(mth5_file, mode="a")
print(mth5_obj.filename)
mth5_obj
# Out:
# /Users/tronan/Desktop/mth5/examples/notebooks/ZU_CAS04NVR08.h5
# /:
# ====================
#     |- Group: Survey
#     ----------------
#         |- Group: Filters
#         -----------------
#             |- Group: coefficient
#             ---------------------
#                 |- Group: v to counts (electric)
#                 --------------------------------
#                 |- Group: v to counts (magnetic)
#                 --------------------------------
#             |- Group: fap
#             -------------
#             |- Group: fir
#             -------------
#             |- Group: time_delay
#             --------------------
#                 |- Group: electric time offset
#                 ------------------------------
#                 |- Group: hx time offset
#                 ------------------------
#                 |- Group: hy time offset
#                 ------------------------
#                 |- Group: hz time offset
#                 ------------------------
#             |- Group: zpk
#             -------------
#                 |- Group: electric field 1 pole butterworth high-pass
#                 -----------------------------------------------------
#                     --> Dataset: poles
#                     ....................
#                     --> Dataset: zeros
#                     ....................
#                 |- Group: electric field 5 pole butterworth low-pass
#                 ----------------------------------------------------
#                     --> Dataset: poles
#                     ....................
#                     --> Dataset: zeros
#                     ....................
#                 |- Group: magnetic field 3 pole butterworth low-pass
#                 ----------------------------------------------------
#                     --> Dataset: poles
#                     ....................
#                     --> Dataset: zeros
#                     ....................
#                 |- Group: mv per km to v per m
#                 ------------------------------
#                     --> Dataset: poles
#                     ....................
#                     --> Dataset: zeros
#                     ....................
#                 |- Group: v per m to v
#                 ----------------------
#                     --> Dataset: poles
#                     ....................
#                     --> Dataset: zeros
#                     ....................
#         |- Group: Reports
#         -----------------
#         |- Group: Standards
#         -------------------
#             --> Dataset: summary
#             ......................
#         |- Group: Stations
#         ------------------
#             |- Group: CAS04
#             ---------------
#                 |- Group: 001
#                 -------------
#                     --> Dataset: ex
#                     .................
#                     --> Dataset: ey
#                     .................
#                     --> Dataset: hx
#                     .................
#                     --> Dataset: hy
#                     .................
#                     --> Dataset: hz
#                     .................
#                 |- Group: 002
#                 -------------
#                     --> Dataset: ex
#                     .................
#                     --> Dataset: ey
#                     .................
#                     --> Dataset: hx
#                     .................
#                     --> Dataset: hy
#                     .................
#                     --> Dataset: hz
#                     .................
#                 |- Group: 003
#                 -------------
#                     --> Dataset: ex
#                     .................
#                     --> Dataset: ey
#                     .................
#                     --> Dataset: hx
#                     .................
#                     --> Dataset: hy
#                     .................
#                     --> Dataset: hz
#                     .................
#                 |- Group: 004
#                 -------------
#                     --> Dataset: ex
#                     .................
#                     --> Dataset: ey
#                     .................
#                     --> Dataset: hx
#                     .................
#                     --> Dataset: hy
#                     .................
#                     --> Dataset: hz
#                     .................
#             |- Group: NVR08
#             ---------------
#                 |- Group: 001
#                 -------------
#                     --> Dataset: ex
#                     .................
#                     --> Dataset: ey
#                     .................
#                     --> Dataset: hx
#                     .................
#                     --> Dataset: hy
#                     .................
#                     --> Dataset: hz
#                     .................
#                 |- Group: 002
#                 -------------
#                     --> Dataset: ex
#                     .................
#                     --> Dataset: ey
#                     .................
#                     --> Dataset: hx
#                     .................
#                     --> Dataset: hy
#                     .................
#                     --> Dataset: hz
#                     .................
#                 |- Group: 003
#                 -------------
#                     --> Dataset: ex
#                     .................
#                     --> Dataset: ey
#                     .................
#                     --> Dataset: hx
#                     .................
#                     --> Dataset: hy
#                     .................
#                     --> Dataset: hz
#                     .................

# %%
# Get time series from MTH5 data
stations = mth5_obj.stations_group.station_summary
stations
# Out:
#       id               start                 end components measurement_type  \
# 0  CAS04 2020-06-02 18:41:43 2020-07-13 21:46:12                        None
# 1  NVR08 2020-06-03 19:10:11 2020-06-24 15:55:46                        None
#
#     latitude   longitude  elevation           hdf5_reference
# 0  37.633351 -121.468382   329.3875  <HDF5 object reference>
# 1  38.326630 -118.082382  1375.4250  <HDF5 object reference>

# %%
mth5_obj.stations_group.channel_summary
# Out:
#    station   run   latitude   longitude  elevation component  \
# 0    CAS04  None  37.633351 -121.468382   329.3875        ex
# 1    CAS04  None  37.633351 -121.468382   329.3875        ey
# 2    CAS04  None  37.633351 -121.468382   329.3875        hx
# 3    CAS04  None  37.633351 -121.468382   329.3875        hy
# 4    CAS04  None  37.633351 -121.468382   329.3875        hz
# 5    CAS04  None  37.633351 -121.468382   329.3875        ex
# 6    CAS04  None  37.633351 -121.468382   329.3875        ey
# 7    CAS04  None  37.633351 -121.468382   329.3875        hx
# 8    CAS04  None  37.633351 -121.468382   329.3875        hy
# 9    CAS04  None  37.633351 -121.468382   329.3875        hz
# 10   CAS04  None  37.633351 -121.468382   329.3875        ex
# 11   CAS04  None  37.633351 -121.468382   329.3875        ey
# 12   CAS04  None  37.633351 -121.468382   329.3875        hx
# 23 2020-06-03 19:10:11 2020-06-03 19:57:51       2861          1.0
# 24 2020-06-03 19:10:11 2020-06-03 19:57:51       2861          1.0
# 25 2020-06-03 20:14:13 2020-06-14 16:56:02     938510          1.0
# 26 2020-06-03 20:14:13 2020-06-14 16:56:02     938510          1.0
# 27 2020-06-03 20:14:13 2020-06-14 16:56:02     938510          1.0
# 28 2020-06-03 20:14:13 2020-06-14 16:56:02     938510          1.0
# 29 2020-06-03 20:14:13 2020-06-14 16:56:02     938510          1.0
# 30 2020-06-14 18:00:44 2020-06-24 15:55:46     856503          1.0
# 31 2020-06-14 18:00:44 2020-06-24 15:55:46     856503          1.0
# 32 2020-06-14 18:00:44 2020-06-24 15:55:46     856503          1.0
# 33 2020-06-14 18:00:44 2020-06-24 15:55:46     856503          1.0
# 34 2020-06-14 18:00:44 2020-06-24 15:55:46     856503          1.0
#
#    measurement_type  azimuth  tilt   units           hdf5_reference
# 0          electric     13.2   0.0  counts  <HDF5 object reference>
# 1          electric    103.2   0.0  counts  <HDF5 object reference>
# 2          magnetic     13.2   0.0  counts  <HDF5 object reference>
# 3          magnetic    103.2   0.0  counts  <HDF5 object reference>
# 4          magnetic      0.0   0.0  counts  <HDF5 object reference>
# 5          electric      0.0   0.0  counts  <HDF5 object reference>
# 6          electric      0.0   0.0  counts  <HDF5 object reference>
# 7          magnetic      0.0   0.0  counts  <HDF5 object reference>
# 8          magnetic      0.0   0.0  counts  <HDF5 object reference>
# 9          magnetic      0.0   0.0  counts  <HDF5 object reference>
# 10         electric      0.0   0.0  counts  <HDF5 object reference>
# 11         electric      0.0   0.0  counts  <HDF5 object reference>
# 12         magnetic      0.0   0.0  counts  <HDF5 object reference>
# 13         magnetic      0.0   0.0  counts  <HDF5 object reference>
# 14         magnetic      0.0   0.0  counts  <HDF5 object reference>
# 15         electric      0.0   0.0  counts  <HDF5 object reference>
# 16         electric      0.0   0.0  counts  <HDF5 object reference>
# 17         magnetic      0.0   0.0  counts  <HDF5 object reference>
# 18         magnetic      0.0   0.0  counts  <HDF5 object reference>
# 19         magnetic      0.0   0.0  counts  <HDF5 object reference>
# 20         electric     12.6   0.0  counts  <HDF5 object reference>
# 21         electric    102.6   0.0  counts  <HDF5 object reference>
# 22         magnetic     12.6   0.0  counts  <HDF5 object reference>
# 23         magnetic    102.6   0.0  counts  <HDF5 object reference>
# 24         magnetic      0.0   0.0  counts  <HDF5 object reference>
# 25         electric      0.0   0.0  counts  <HDF5 object reference>
# 26         electric      0.0   0.0  counts  <HDF5 object reference>
# 27         magnetic      0.0   0.0  counts  <HDF5 object reference>
# 28         magnetic      0.0   0.0  counts  <HDF5 object reference>
# 29         magnetic      0.0   0.0  counts  <HDF5 object reference>
# 30         electric      0.0   0.0  counts  <HDF5 object reference>
# 31         electric      0.0   0.0  counts  <HDF5 object reference>
# 32         magnetic      0.0   0.0  counts  <HDF5 object reference>
# 33         magnetic      0.0   0.0  counts  <HDF5 object reference>
# 34         magnetic      0.0   0.0  counts  <HDF5 object reference>

# %%
# Get the time series from a channel summary
